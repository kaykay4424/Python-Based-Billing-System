# %%
print(" Welcome to M&K Innovations Pvt. Ltd, \n")
print(" Please provide us with the following information so that we may help you in the best way possible:) \n")

name = input(" Please enter your name: ")
city = input(" Please enter your city: ")

house_types = {
    1: 'Duplex',
    2: 'Apartment',
    3: 'Villa',
    4: 'Flats',
    5: 'Bungalow',
    6: 'Farmhouse',
    7: 'Penthouse'
}

print("\n Please select the type of your house:")
for code, htype in house_types.items():
    print(f"{htype} = {code}")

while True:
    try:
        h = int(input("\n Enter house type code: "))
        if h in house_types:
            break
        else:
            print(" Invalid code. Try again.")
    except ValueError:
        print(" Enter a number.")

a = int(input("\n Enter the area in sq.ft: "))

material_input = input("\n Will you provide the material? (yes/no): ").lower()
mc = 0 if material_input == "yes" else 200000

flooring_rates = {
    'hardwood': 200,
    'tile': 50,
    'marble': 150,
    'vinyl': 100,
    'carpet': 70
}

print("\n Flooring Options:")
for k, v in flooring_rates.items():
    print(f"{k.capitalize()} (Rs.{v}/sq.ft.)")

while True:
    flooring = input("\n Enter flooring type: ").lower()
    if flooring in flooring_rates:
        break
    else:
        print(" Invalid choice. Try again.")
fa = int(input(" Enter flooring area in sq.ft: "))
fc = flooring_rates[flooring] * fa

ceiling_rates = {
    'metal': 275,
    'pop': 55,
    'gypsum': 70,
    'aluminium': 200,
    'wooden': 150
}

print("\n Ceiling Options:")
for k, v in ceiling_rates.items():
    print(f"{k.capitalize()} (Rs.{v}/sq.ft.)")

while True:
    ceiling = input("\n Enter ceiling type: ").lower()
    if ceiling in ceiling_rates:
        break
    else:
        print(" Invalid choice. Try again.")
ca = int(input(" Enter ceiling area in sq.ft: "))
cc = ceiling_rates[ceiling] * ca

wall_rates = {
    'distemper': 30,
    'enamel': 25,
    'matte': 50,
    'high gloss': 60,
    'semi gloss': 40
}

print("\n Wall Finish Options:")
for k, v in wall_rates.items():
    print(f"{k.title()} (Rs.{v}/sq.ft.)")

while True:
    wall = input("\n Enter wall finish type: ").lower()
    if wall in wall_rates:
        break
    else:
        print(" Invalid choice. Try again.")
wa = int(input(" Enter wall area in sq.ft: "))
wc = wall_rates[wall] * wa

lc = a * 50  # Labour cost

# Payment Method
payment_methods = ['debit card', 'credit card', 'cheque', 'cash']
mp = input("\n Enter preferred mode of payment: ").lower()
if mp not in payment_methods:
    mp = "unspecified"

# Totals
ta = mc + lc + fc + cc + wc
tax = 0.18 * ta
gt = ta + tax

# Final Bill
print("\n" + "="*60)
print("                M&K INNOVATIONS PVT. LTD.")
print("            Innovation becomes reality here")
print("="*60)
print("Dated: 23/07/2025                    Bill No: BKMD14-284")
print(f"Customer Name: {name}")
print(f"City: {city}")
print(f"Type of House: {house_types[h]}")
print(f"Area: {a} sq.ft.")
print("-" * 60)
print(f"Material Charges:                  Rs. {mc}")
print(f"Labour Charges:                    Rs. {lc}")
print(f"Flooring Charges ({flooring}):     Rs. {fc}")
print(f"Ceiling Charges ({ceiling}):       Rs. {cc}")
print(f"Wall Finish Charges ({wall}):      Rs. {wc}")
print("-" * 60)
print(f"Total Amount:                      Rs. {ta}")
print(f"Tax (18%):                         Rs. {tax:.2f}")
print(f"Grand Total:                       Rs. {gt:.2f}")
print(f"Mode of Payment:                   {mp.capitalize()}")
print("="*60)
print("\nTHANK YOU FOR SHOPPING WITH US!")
print(f"\n{name}")
print("____________________________")
print("Customer's Signature")





import json
import os


bill_data = {
    "name": name,
    "city": city,
    "house_type": house_types[h],
    "area_sqft": a,
    "material_provided": material_input,
    "material_cost": mc,
    "labour_cost": lc,
    "flooring_type": flooring,
    "flooring_area": fa,
    "flooring_cost": fc,
    "ceiling_type": ceiling,
    "ceiling_area": ca,
    "ceiling_cost": cc,
    "wall_finish": wall,
    "wall_area": wa,
    "wall_cost": wc,
    "total_amount": ta,
    "tax": round(tax, 2),
    "grand_total": round(gt, 2),
    "payment_mode": mp
}


filename = "billing_data.json"


if os.path.exists(filename):
    with open(filename, 'r') as f:
        try:
            all_data = json.load(f)
        except json.JSONDecodeError:
            all_data = []
else:
    all_data = []


all_data.append(bill_data)

with open(filename, 'w') as f:
    json.dump(all_data, f, indent=4)

print("\n[✅] Billing record saved to billing_data.json")
# Out:
#  Welcome to M&K Innovations Pvt. Ltd,
#
#  Please provide us with the following information so that we may help you in the best way possible:)
#  Please enter your name:  kk
#  Please enter your city:  asr
#  Please select the type of your house:
# Duplex = 1
# Apartment = 2
# Villa = 3
# Flats = 4
# Bungalow = 5
# Farmhouse = 6
# Penthouse = 7
#  Enter house type code:  7
#
#  Enter the area in sq.ft:  200000
#
#  Will you provide the material? (yes/no):  yes
#  Flooring Options:
# Hardwood (Rs.200/sq.ft.)
# Tile (Rs.50/sq.ft.)
# Marble (Rs.150/sq.ft.)
# Vinyl (Rs.100/sq.ft.)
# Carpet (Rs.70/sq.ft.)
#  Enter flooring type:  vinyl
#  Enter flooring area in sq.ft:  500
#  Ceiling Options:
# Metal (Rs.275/sq.ft.)
# Pop (Rs.55/sq.ft.)
# Gypsum (Rs.70/sq.ft.)
# Aluminium (Rs.200/sq.ft.)
# Wooden (Rs.150/sq.ft.)
#  Enter ceiling type:  pop
#  Enter ceiling area in sq.ft:  400
#  Wall Finish Options:
# Distemper (Rs.30/sq.ft.)
# Enamel (Rs.25/sq.ft.)
# Matte (Rs.50/sq.ft.)
# High Gloss (Rs.60/sq.ft.)
# Semi Gloss (Rs.40/sq.ft.)
#  Enter wall finish type:  semi gloss
#  Enter wall area in sq.ft:  500
#
#  Enter preferred mode of payment:  cash
# ============================================================
#                 M&K INNOVATIONS PVT. LTD.
#             Innovation becomes reality here
# ============================================================
# Dated: 23/07/2025                    Bill No: BKMD14-284
# Customer Name: kk
# City: asr
# Type of House: Penthouse
# Area: 200000 sq.ft.
# ------------------------------------------------------------
# Material Charges:                  Rs. 0
# Labour Charges:                    Rs. 10000000
# Flooring Charges (vinyl):     Rs. 50000
# Ceiling Charges (pop):       Rs. 22000
# Wall Finish Charges (semi gloss):      Rs. 20000
# ------------------------------------------------------------
# Total Amount:                      Rs. 10092000
# Tax (18%):                         Rs. 1816560.00
# Grand Total:                       Rs. 11908560.00
# Mode of Payment:                   Cash
# ============================================================
#
# THANK YOU FOR SHOPPING WITH US!
#
# kk
# ____________________________
# Customer's Signature
#
# [✅] Billing record saved to billing_data.json

# %%
# Out:
# [✅] Billing record saved to billing_data.json
